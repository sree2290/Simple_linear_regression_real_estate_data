# %% [markdown]
# # Simple Linear Regression Using traditional Statictical Methods

# %% [markdown]
# ### Importing Necessary Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
import seaborn as sns
sns.set()

# %%
data = pd.read_csv("real_estate_price_size.csv")
data
# Out:
#          price     size
# 0   234314.144   643.09
# 1   228581.528   656.22
# 2   281626.336   487.29
# 3   401255.608  1504.75
# 4   458674.256  1275.46
# ..         ...      ...
# 95  252460.400   549.80
# 96  310522.592  1037.44
# 97  383635.568  1504.75
# 98  225145.248   648.29
# 99  274922.856   705.29
#
# [100 rows x 2 columns]

# %% [markdown]
# ### Discriptive Statistics

# %%
data.describe()
# Out:
#                price         size
# count     100.000000   100.000000
# mean   292289.470160   853.024200
# std     77051.727525   297.941951
# min    154282.128000   479.750000
# 25%    234280.148000   643.330000
# 50%    280590.716000   696.405000
# 75%    335723.696000  1029.322500
# max    500681.128000  1842.510000

# %%
y = data["price"]
X1 = data["size"]

# %% [markdown]
# ### Scatter Plot for Two numarical Variables

# %%
plt.scatter(X1,y);

# %% [markdown]
# ### Statistics of the Model using StatsModels.api

# %%
x = sm.add_constant(X1)
results = sm.OLS(y,x).fit()
results.summary()
# Out:
# C:\Users\SREE\anaconda3\lib\site-packages\statsmodels\tsa\tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.745
# Model:                            OLS   Adj. R-squared:                  0.742
# Method:                 Least Squares   F-statistic:                     285.9
# Date:                Sat, 21 May 2022   Prob (F-statistic):           8.13e-31
# Time:                        14:55:32   Log-Likelihood:                -1198.3
# No. Observations:                 100   AIC:                             2401.
# Df Residuals:                      98   BIC:                             2406.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...

# %% [markdown]
# ### Drew a Linear line to conncet all dots

# %%
plt.scatter(X1,y)
yhat =   223.1787* X1 + 1.019e+05	
fig = plt.plot(X1,yhat, c = "red", lw = 2)

# %% [markdown]
# yhat = bo + b1 xi = E0

# %% [markdown]
# ![Screen.png](attachment:Screen.png)
